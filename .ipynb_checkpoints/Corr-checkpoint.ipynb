# %%
import pandas as pd
import numpy as np
#from scipy.stats import pearsonr

# %%
# Importing the dataset
dataset = pd.read_csv("/scratch/ope4/MERGE/DEC-04-2024/damage_points_cropped.csv")


# Drop the 'Unnamed: 0' column from the DataFrame
#dataset = dataset.drop(columns=['Unnamed: 0'])

# Check the columns after dropping
print(dataset.columns)

# Drop multiple columns
dataset.drop(['SURVEY_YEAR', 'geom', 'prec', 'tmax', 'tmin'], axis=1, inplace=True)
# Out:
# Index(['LANDSAT_1', 'LANDSAT_2', 'LANDSAT_3', 'LANDSAT_4', 'LANDSAT_5',
#        'LANDSAT_6', 'LANDSAT_7', 'LANDSAT_8', 'SURVEY_YEAR', 'prec', 'tmax',
#        'tmin', 'geom', 'STATUS'],
#       dtype='object')

# %%
correlation_matrix = dataset.corr()

print(correlation_matrix)
# Out:
#            LANDSAT_1  LANDSAT_2  LANDSAT_3  LANDSAT_4  LANDSAT_5  LANDSAT_6  \
# LANDSAT_1   1.000000   0.993607   0.959101   0.894384   0.516896   0.449383
# LANDSAT_2   0.993607   1.000000   0.977591   0.928540   0.528929   0.502147
# LANDSAT_3   0.959101   0.977591   1.000000   0.968581   0.596458   0.596932
# LANDSAT_4   0.894384   0.928540   0.968581   1.000000   0.528430   0.709473
# LANDSAT_5   0.516896   0.528929   0.596458   0.528430   1.000000   0.438592
# LANDSAT_6   0.449383   0.502147   0.596932   0.709473   0.438592   1.000000
# LANDSAT_7   0.486259   0.539430   0.623473   0.748268   0.312399   0.965748
# LANDSAT_8   0.027052   0.045073   0.088056   0.149244   0.035924   0.510042
# prec       -0.008811  -0.011092  -0.040106  -0.051451  -0.024664  -0.153035
# tmax        0.099524   0.093913   0.086418   0.108777  -0.111558   0.173741
# tmin        0.054871   0.041899   0.033207   0.024159   0.011694   0.091670
# STATUS      0.074126   0.067052   0.057360   0.033694   0.044968   0.008237
#
#            LANDSAT_7  LANDSAT_8      prec      tmax      tmin    STATUS
# LANDSAT_1   0.486259   0.027052 -0.008811  0.099524  0.054871  0.074126
# LANDSAT_2   0.539430   0.045073 -0.011092  0.093913  0.041899  0.067052
# LANDSAT_3   0.623473   0.088056 -0.040106  0.086418  0.033207  0.057360
# LANDSAT_4   0.748268   0.149244 -0.051451  0.108777  0.024159  0.033694
# LANDSAT_5   0.312399   0.035924 -0.024664 -0.111558  0.011694  0.044968
# LANDSAT_6   0.965748   0.510042 -0.153035  0.173741  0.091670  0.008237
# LANDSAT_7   1.000000   0.501492 -0.164535  0.197540  0.081475  0.003358
# LANDSAT_8   0.501492   1.000000 -0.268018  0.440805  0.321854  0.021743
# prec       -0.164535  -0.268018  1.000000 -0.101126  0.023681  0.039107
# tmax        0.197540   0.440805 -0.101126  1.000000  0.810678 -0.024957
# tmin        0.081475   0.321854  0.023681  0.810678  1.000000 -0.023121
# STATUS      0.003358   0.021743  0.039107 -0.024957 -0.023121  1.000000
